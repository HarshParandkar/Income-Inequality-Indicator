# %% [markdown]
# **IMPORTING THE LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("/content/Hack-O-Mania.xlsx")

# %%
data.head()
# Out:
#     area subarea country   c3 interpolated  id    region_wb  \
# 0  World   World   World  NaN          NaN NaN  All regions
# 1  World   World   World  NaN          NaN NaN  All regions
# 2  World   World   World  NaN          NaN NaN  All regions
# 3  World   World   World  NaN          NaN NaN  All regions
# 4  World   World   World  NaN          NaN NaN  All regions
#
#          incomegroup  year    population  ...       y91       y92       y93  \
# 0  All income groups  1950  2.536165e+09  ...  11017.54  11752.50  12696.34
# 1  All income groups  1951  2.583738e+09  ...  11508.75  12303.24  13290.44
# 2  All income groups  1952  2.630538e+09  ...  11746.71  12540.02  13526.04
# 3  All income groups  1953  2.677255e+09  ...  12191.45  13068.38  14136.01
# 4  All income groups  1954  2.724464e+09  ...  12402.17  13248.59  14272.51
#
#         y94       y95       y96       y97       y98       y99      y100
# 0  13839.34  15213.67  16877.18  19097.49  22516.21  28512.81  49393.06
# ...

# %%
data.columns
# Out:
# Index(['area', 'subarea', 'country', 'c3', 'interpolated', 'id', 'region_wb',
#        'incomegroup', 'year', 'population',
#        ...
#        'y91', 'y92', 'y93', 'y94', 'y95', 'y96', 'y97', 'y98', 'y99', 'y100'],
#       dtype='object', length=252)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16046 entries, 0 to 16045
# Columns: 252 entries, area to y100
# dtypes: float64(244), int64(1), object(7)
# memory usage: 30.9+ MB

# %%
data.shape
# Out:
# (16046, 252)

# %%
data.isnull().sum()
# Out:
# area               0
# subarea            0
# country            0
# c3              1207
# interpolated    1207
#                 ...
# y96              294
# y97              284
# y98              284
# y99              284
# y100             284
# Length: 252, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data1=data.filter(items=['area','subarea','country','region_wb','year','population','gdp','gini','ge1','a025','palma','middle50','ginia','sd','dy5','y50'])
data1
# Out:
#           area  subarea   country           region_wb  year    population  \
# 0        World    World     World         All regions  1950  2.536165e+09
# 1        World    World     World         All regions  1951  2.583738e+09
# 2        World    World     World         All regions  1952  2.630538e+09
# 3        World    World     World         All regions  1953  2.677255e+09
# 4        World    World     World         All regions  1954  2.724464e+09
# ...        ...      ...       ...                 ...   ...           ...
# 16041  Country  Country  Zimbabwe  Sub-Saharan Africa  2016  1.403034e+07
# 16042  Country  Country  Zimbabwe  Sub-Saharan Africa  2017  1.423660e+07
# 16043  Country  Country  Zimbabwe  Sub-Saharan Africa  2018  1.443881e+07
# 16044  Country  Country  Zimbabwe  Sub-Saharan Africa  2019  1.464547e+07
# 16045  Country  Country  Zimbabwe  Sub-Saharan Africa  2020  1.486293e+07
#
#            gdp    gini     ge1    a025   palma  middle50       ginia  \
# ...

# %%
data1.isnull().sum()
# Out:
# area            0
# subarea         0
# country         0
# region_wb     355
# year            0
# population     71
# gdp            71
# gini           71
# ge1            71
# a025           71
# palma          40
# middle50       40
# ginia          71
# sd             71
# dy5           286
# y50           284
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16046 entries, 0 to 16045
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area        16046 non-null  object
#  1   subarea     16046 non-null  object
#  2   country     16046 non-null  object
#  3   region_wb   15691 non-null  object
#  4   year        16046 non-null  int64
#  5   population  15975 non-null  float64
#  6   gdp         15975 non-null  float64
#  7   gini        15975 non-null  float64
#  8   ge1         15975 non-null  float64
#  9   a025        15975 non-null  float64
#  10  palma       16006 non-null  float64
#  11  middle50    16006 non-null  float64
#  12  ginia       15975 non-null  float64
#  13  sd          15975 non-null  float64
#  14  dy5         15760 non-null  float64
#  15  y50         15762 non-null  float64
# dtypes: float64(11), int64(1), object(4)
# memory usage: 2.0+ MB

# %% [markdown]
# Explonatary Data Analysis

# %% [markdown]
# **UNIVARIATE ANALYSIS**

# %%
plt.plot(data1.area)
plt.title("Area Plot")
plt.show()

# %%
plt.plot(data1.gdp)
plt.title("gdp Plot")
plt.show()

# %% [markdown]
# It helps to understand and describe individual characteristics of a single variable without worrying about how it relates to other things.

# %% [markdown]
# **BIVARIATE ANALYSIS**

# %%
sns.scatterplot(x=data1.country,y=data1.gdp)
plt.show()

# %%
sns.scatterplot(x=data1.palma,y=data1.ge1)
plt.show()

# %% [markdown]
# Bivariate analysis involves the analysis of two variables to understand the relationship between them. Bivariate analysis explores how changes in one variable may be related to changes in another. It helps in identifying patterns, correlations, or associations between two variables.

# %% [markdown]
# **MULTIVARIATE ANALYSIS**

# %%
plt.figure(figsize=(10,20))
sns.heatmap(data1.corr(),annot=True )
# Out:
# <ipython-input-17-e5a98c963d19>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data1.corr(),annot=True )
# <Axes: >

# %% [markdown]
# It extends linear regression to multiple independent variables. It models the relationship between a dependent variable and two or more independent variables.

# %% [markdown]
# **HANDLING MISSING VALUES**

# %%
data1.isnull().sum()
# Out:
# area            0
# subarea         0
# country         0
# region_wb     355
# year            0
# population     71
# gdp            71
# gini           71
# ge1            71
# a025           71
# palma          40
# middle50       40
# ginia          71
# sd             71
# dy5           286
# y50           284
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
si=SimpleImputer(strategy='most_frequent')

# %%
data1['region_wb']=si.fit_transform(data1[['region_wb']])

# %%
si=SimpleImputer(strategy='median')

# %%
data1['population']=si.fit_transform(data1[['population']])
data1['gdp']=si.fit_transform(data1[['gdp']])
data1['gini']=si.fit_transform(data1[['gini']])

# %%
si=SimpleImputer(strategy='mean')

# %%
data1['ge1']=si.fit_transform(data1[['ge1']])
data1['a025']=si.fit_transform(data1[['a025']])
data1['palma']=si.fit_transform(data1[['palma']])
data1['middle50']=si.fit_transform(data1[['middle50']])
data1['ginia']=si.fit_transform(data1[['ginia']])
data1['sd']=si.fit_transform(data1[['sd']])
data1['dy5']=si.fit_transform(data1[['dy5']])
data1['y50']=si.fit_transform(data1[['y50']])

# %%
data1.isnull().sum()
# Out:
# area          0
# subarea       0
# country       0
# region_wb     0
# year          0
# population    0
# gdp           0
# gini          0
# ge1           0
# a025          0
# palma         0
# middle50      0
# ginia         0
# sd            0
# dy5           0
# y50           0
# dtype: int64

# %% [markdown]
# Handling missing values is an essential step in data preprocessing to ensure the quality and reliability of data analysis.

# %% [markdown]
# **HANDLING CATEGORICAL DATA**

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
data1['area']=encoder.fit_transform(data1['area'])
data1['subarea']=encoder.fit_transform(data1['subarea'])
data1['country']=encoder.fit_transform(data1['country'])
data1['region_wb']=encoder.fit_transform(data1['region_wb'])

# %% [markdown]
# Handling categorical data is a crucial step in data preprocessing, as many machine learning algorithms require numerical input.Label encoding method is suitable for ordinal data.

# %% [markdown]
# **SPLITTING**

# %%
X=data1.drop("gini",axis=1)
Y=data1[["gini"]]

# %% [markdown]
# This allow to train a machine learning model on one subset of the data and evaluate its performance on another unseen subset.

# %% [markdown]
# **SCALING**

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
scaler=StandardScaler()

# %%
col=X.columns

# %%
scaled=scaler.fit_transform(X)

# %%
X=pd.DataFrame(scaled,columns=col)

# %%
X
# Out:
#            area   subarea   country  region_wb      year  population  \
# 0      5.017793  4.517861  1.622628  -1.587330 -1.707825    3.265277
# 1      5.017793  4.517861  1.622628  -1.587330 -1.659030    3.330485
# 2      5.017793  4.517861  1.622628  -1.587330 -1.610235    3.394634
# 3      5.017793  4.517861  1.622628  -1.587330 -1.561440    3.458668
# 4      5.017793  4.517861  1.622628  -1.587330 -1.512645    3.523378
# ...         ...       ...       ...        ...       ...         ...
# 16041 -0.264915 -0.248198  1.668726   1.599416  1.512645   -0.191797
# 16042 -0.264915 -0.248198  1.668726   1.599416  1.561440   -0.191515
# 16043 -0.264915 -0.248198  1.668726   1.599416  1.610235   -0.191238
# 16044 -0.264915 -0.248198  1.668726   1.599416  1.659030   -0.190954
# 16045 -0.264915 -0.248198  1.668726   1.599416  1.707825   -0.190656
#
#             gdp       ge1      a025     palma  middle50     ginia        sd  \
# ...

# %% [markdown]
# Scaling is a preprocessing step in machine learning that involves transforming the numerical features of a dataset so that they all have a similar scale.

# %% [markdown]
# **TRAIN, TEST, SPLIT**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,train_size=0.8,random_state=42)
x_train.head()
# Out:
#            area   subarea   country  region_wb      year  population  \
# 15215 -0.264915 -0.248198  1.545797  -0.676831 -0.683130   -0.193968
# 11385 -0.264915 -0.248198  0.593094   1.144166 -0.487950   -0.119443
# 9022  -0.264915 -0.248198  0.009179  -0.676831 -1.463850   -0.207425
# 14709 -0.264915 -0.248198  1.422868  -1.132080 -1.122285   -0.211021
# 185    5.017793  5.984340  1.622628  -1.587330  0.390360    7.438185
#
#             gdp       ge1      a025     palma  middle50     ginia        sd  \
# 15215 -0.532043 -1.165343 -1.015045 -0.508027  0.538792 -0.639446 -0.712477
# 11385 -0.622474  0.013348 -0.032750 -0.182166 -0.334113 -0.662672 -0.699370
# 9022  -0.275584 -0.888494 -0.786496 -0.439748  0.058232 -0.375039 -0.409743
# 14709 -0.676459 -0.533317 -0.459531 -0.326494  0.329117 -0.741661 -0.802604
# 185   -0.212454 -0.191201 -0.154643 -0.241451  0.185693 -0.111086  0.062077
#
#             dy5           y50
# 15215 -0.460804 -4.644906e-01
# 11385 -0.584722 -5.850712e-01
# ...

# %%
y_train.head()
# Out:
#          gini
# 15215  28.021
# 11385  46.348
# 9022   32.607
# 14709  40.146
# 185    43.907

# %%
x_test.head()
# Out:
#            area   subarea   country  region_wb      year  population  \
# 12097 -0.264915 -0.248198  0.654559  -0.221582 -0.390360   -0.207005
# 5484  -0.264915 -0.248198 -0.743764   1.599416 -0.878310   -0.175007
# 6167  -0.264915 -0.248198 -0.528637   1.599416  1.268670   -0.196745
# 11676 -0.264915 -0.248198  0.608460  -1.132080 -0.146385   -0.211012
# 14000 -0.264915 -0.248198 -1.143285   1.599416 -1.073490   -0.206665
#
#             gdp       ge1      a025     palma  middle50     ginia        sd  \
# 12097 -0.381555  0.943658  0.761575  0.322979 -0.449452 -0.239904 -0.143521
# 5484  -0.676754  1.144607  0.861546  0.273712 -1.084598 -0.722368 -0.758037
# 6167  -0.615324  0.398333  0.284109 -0.031910 -0.371799 -0.640622 -0.662044
# 11676 -0.288361 -0.337098 -0.317893 -0.300327 -0.072109 -0.272122 -0.262655
# 14000 -0.642709 -0.376451 -0.369355 -0.321383 -0.143521 -0.702704 -0.746413
#
#             dy5       y50
# 12097 -0.431996 -0.430644
# 5484  -0.631408 -0.631594
# ...

# %%
y_test.head()
# Out:
#          gini
# 12097  56.968
# 5484   57.308
# 6167   50.659
# 11676  41.950
# 14000  40.172

# %% [markdown]
# The train_test_split method is a common technique in machine learning for dividing a dataset into training and testing sets. This separation allows you to train your model on one subset of the data and evaluate its performance on another, unseen subset.

# %% [markdown]
# **MODEL BUILDING**

# %% [markdown]
# **LINEAR REGRESSION**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
def Regression(x_train,y_train,x_test,y_test):
  regressor=LinearRegression()
  regressor.fit(x_train,y_train)
  predictions=regressor.predict(x_test)
  mse=mean_squared_error(y_test,predictions)
  r2=r2_score(y_test,predictions)
  print("Mean Squared Error:",mse)
  print("R2 Score:",r2)

Regression(x_train,y_train,x_test,y_test)
# Out:
# Mean Squared Error: 3.4790550892422507
# R2 Score: 0.975913102240982

# %% [markdown]
# Linear regression is a supervised machine learning algorithm used for predicting a continuous outcome variable based on one or more predictor variables.

# %% [markdown]
# **DECISION TREE**

# %%
from sklearn.tree import DecisionTreeRegressor
def Decision(x_train,y_train,x_test,y_test):
  model = DecisionTreeRegressor(random_state=42)
  model.fit(x_train, y_train)
  y_pred = model.predict(x_test)
  mse = mean_squared_error(y_test, y_pred)
  r2 = r2_score(y_test, y_pred)
  print("Mean Squared Error:",mse)
  print("R^2 Score:",r2)

Decision(x_train,y_train,x_test,y_test)
# Out:
# Mean Squared Error: 0.056619675700934624
# R^2 Score: 0.9996079992110576

# %% [markdown]
#  It creates a model in the form of a tree structure where each node represents a decision based on the value of a particular feature.

# %% [markdown]
# **RANDOM FOREST**

# %%
from sklearn.ensemble import RandomForestRegressor
rdf=RandomForestRegressor()

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
def Random_Forest(x_train,x_test,y_train,y_test):
  rdf=RandomForestRegressor()
  random=rdf.fit(x_train,y_train)
  predict_random=random.predict(x_test)
  print("R2 Score:",r2_score(y_test,predict_random))
  print("Mean Squared Error",mean_squared_error(y_test,predict_random))
  print("Mean Absolute Error",mean_absolute_error(y_test,predict_random))

Random_Forest(x_train,x_test,y_train,y_test)
# Out:
# <ipython-input-43-edf7e8263439>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random=rdf.fit(x_train,y_train)
# R2 Score: 0.9998149230778749
# Mean Squared Error 0.026732077092804077
# Mean Absolute Error 0.07691280685360054

# %% [markdown]
# Random Forest builds several decision trees during training and merges their predictions to provide a more stable and accurate result.

# %% [markdown]
# **POLYNOMIAL REGRESSION**

# %%
from sklearn.preprocessing import PolynomialFeatures
def Polynomial(x_train,y_train,x_test,y_test):
  poly=PolynomialFeatures(degree=2)
  X_poly=poly.fit_transform(x_train)
  model = DecisionTreeRegressor(random_state=42)
  model.fit(X_poly,y_train)
  x_test_poly=poly.transform(x_test)
  predictions=model.predict(x_test_poly)
  mse=mean_squared_error(y_test,predictions)
  print("Mean Squared Error:",mse)
  r2=r2_score(y_test,predictions)
  print("R2 Score:",r2)

Polynomial(x_train,y_train,x_test,y_test)
# Out:
# Mean Squared Error: 0.08584129937694707
# R2 Score: 0.9994056861565696

# %% [markdown]
# Polynomial regression is a form of linear regression in which the relationship between the independent variable x and the dependent variable y is modeled as an n-th degree polynomial.

# %% [markdown]
# **COMPARISON**

# %%
def Comparision(x_train,x_test,y_train,y_test):
  print("LINEAR REGRESSION:")
  Regression(x_train,y_train,x_test,y_test)
  print()
  print("DECISION TREE REGRESSION")
  Decision(x_train,y_train,x_test,y_test)
  print()
  print("RANDOM FOREST REGRESSION")
  Random_Forest(x_train,x_test,y_train,y_test)
  print()
  print("POLYNOMIAL REGRESSION")
  Polynomial(x_train,y_train,x_test,y_test)
  print()


Comparision(x_train,x_test,y_train,y_test)
# Out:
# LINEAR REGRESSION:
# Mean Squared Error: 3.4790550892422507
# R2 Score: 0.975913102240982
#
# DECISION TREE REGRESSION
# Mean Squared Error: 0.056619675700934624
# R^2 Score: 0.9996079992110576
#
# RANDOM FOREST REGRESSION
# <ipython-input-43-edf7e8263439>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random=rdf.fit(x_train,y_train)
# R2 Score: 0.9998174173140462
# Mean Squared Error 0.02637181546292866
# Mean Absolute Error 0.07657330841123254
#
# POLYNOMIAL REGRESSION
# Mean Squared Error: 0.08584129937694707
# R2 Score: 0.9994056861565696

# %% [markdown]
# When choosing a regression model, it's important to compare different models to select the one that best fits data and provides the most accurate predictions. Here, we have provide a simple comparison of linear regression, polynomial regression,decisiontree and random forest regression.

# %% [markdown]
# **Testing**

# %%
x_train.head()
# Out:
#            area   subarea   country  region_wb      year  population  \
# 15215 -0.264915 -0.248198  1.545797  -0.676831 -0.683130   -0.193968
# 11385 -0.264915 -0.248198  0.593094   1.144166 -0.487950   -0.119443
# 9022  -0.264915 -0.248198  0.009179  -0.676831 -1.463850   -0.207425
# 14709 -0.264915 -0.248198  1.422868  -1.132080 -1.122285   -0.211021
# 185    5.017793  5.984340  1.622628  -1.587330  0.390360    7.438185
#
#             gdp       ge1      a025     palma  middle50     ginia        sd  \
# 15215 -0.532043 -1.165343 -1.015045 -0.508027  0.538792 -0.639446 -0.712477
# 11385 -0.622474  0.013348 -0.032750 -0.182166 -0.334113 -0.662672 -0.699370
# 9022  -0.275584 -0.888494 -0.786496 -0.439748  0.058232 -0.375039 -0.409743
# 14709 -0.676459 -0.533317 -0.459531 -0.326494  0.329117 -0.741661 -0.802604
# 185   -0.212454 -0.191201 -0.154643 -0.241451  0.185693 -0.111086  0.062077
#
#             dy5           y50
# 15215 -0.460804 -4.644906e-01
# 11385 -0.584722 -5.850712e-01
# ...

# %% [markdown]
# **CHOSEN MODEL CODE:**

# %%
rdf=RandomForestRegressor()
random=rdf.fit(x_train,y_train)
predict_random=random.predict(x_test)
print("R2 Score:",r2_score(y_test,predict_random))
print("Mean Squared Error",mean_squared_error(y_test,predict_random))
print("Mean Absolute Error",mean_absolute_error(y_test,predict_random))
# Out:
# <ipython-input-47-e9638ecd84be>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random=rdf.fit(x_train,y_train)
# R2 Score: 0.9998140357412589
# Mean Squared Error 0.026860241915046913
# Mean Absolute Error 0.07696738629285291

# %% [markdown]
# **SAMPLE TEST CASES:**

# %%
random.predict([[-0.264915,	-0.248198,	1.545797,	-0.676831,	-0.683130,	-0.193968,	-0.532043,-1.165343,	-1.015045,	-0.508027,	0.538792,	-0.639446,	-0.712477,	-0.460804,	-4.644906e-01]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([28.021])

# %%
random.predict([[-0.264915,	-0.248198,	0.593094,	1.144166,	-0.487950,	-0.119443,	-0.622474,	0.013348,	-0.032750,	-0.182166,	-0.334113,	-0.662672,	-0.699370,	-0.584722,	-5.850712e-01]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([46.33191])

# %%
random.predict([[5.017793,	5.984340, 1.622628,	-1.587330,	0.390360,	7.438185,	-0.212454,	-0.191201,	-0.154643,	-0.241451,	0.185693,	-0.111086,	0.062077,	0.000000,	-1.132366e-16]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([44.03512])

# %%
random.predict([[-0.264915,	-0.248198,	1.422868,	-1.132080,	-1.122285,	-0.211021,	-0.676459,	-0.533317,	-0.459531,	-0.326494,	0.329117,	-0.741661,	-0.802604,	-0.618893,	-6.198236e-01]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([40.146])

# %%
random.predict([[-0.264915,	-0.248198,	0.009179,	-0.676831,	-1.463850,	-0.207425,	-0.275584,	-0.888494,	-0.786496,	-0.439748,	0.058232,	-0.375039,	-0.409743,	-0.217640,	-2.331752e-01]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([32.607])

# %% [markdown]
# It can be used for more robust model evaluation.

# %% [markdown]
# **SAVING THE MODEL**

# %%
import pickle
with open('random.pkl','wb') as file:
  pickle.dump(random,file)

# %% [markdown]
# Saving a trained machine learning model as a pickle file in Python is a common way to store the model so that it can be easily loaded and reused later.

# %%
from joblib import dump

dump(random, 'model.joblib')
# Out:
# ['model.joblib']

# %%
random
# Out:
# RandomForestRegressor()
